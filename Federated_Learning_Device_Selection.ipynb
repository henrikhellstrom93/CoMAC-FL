# %%
#--Simulation settings--
num_rounds = 50 # Number of communication rounds
num_devices = 10 # Number of devices
SNR_req = 10 #Required SNR (participation threshold)
SNR_mean = 11 #Mean SNR (mean SNR of devices)
SNR_var = 2 #SNR variance (variance of SNR distribution)
bs = 50 # Batch size for local training at devices
ep = 2 # Number of local epochs before communication round
filename = "SNR-10-devices-10-selection-false"

# %%
#--Load MNIST dataset--
import tensorflow as tf
import time
import numpy as np

mnist = tf.keras.datasets.mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train/255, x_test/255

num_samples = len(x_train)

#Split dataset into shards
samples_per_shard = int(num_samples/num_devices)
x_train_shards = []
y_train_shards = []
for i in range(num_devices):
    x_train_shard = x_train[i*samples_per_shard:(i+1)*samples_per_shard]
    x_train_shards.append(x_train_shard)
    y_train_shard = y_train[i*samples_per_shard:(i+1)*samples_per_shard]
    y_train_shards.append(y_train_shard)

print("Dataset loaded.")
# Out:
# Dataset loaded.

# %%
#--Set up DNN models--
model_template = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10)
])

model_list = []

#Create user device models and global model
global_model = tf.keras.models.clone_model(model_template)
for i in range(num_devices):
    model_list.append(tf.keras.models.clone_model(model_template))

loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

#Compile all models to initiate weights
for model in model_list:
    model.compile(optimizer='adam', loss=loss_fn, metrics=['accuracy'])

#Broadcast global model to all user devices
global_weights = global_model.get_weights()
for model in model_list:
    model.set_weights(global_weights)
    
#Select random SNR for each device
#device_SNR = np.random.normal(SNR_mean, SNR_var, (num_devices, 1))
#print(device_SNR)
#device_SNR = [7.1, 15.0, 13.4, 9.6, 10.0, 13.3, 11.1, 10.5, 8.1, 11.9]
device_SNR = [10.0, 15.0, 13.4, 10.0, 10.0, 13.3, 11.1, 10.5, 10.0, 11.9]
#Exclude devices below threshold
min_SNR = max(device_SNR)
to_remove = []
for d in range(num_devices):
    if device_SNR[d] < SNR_req:
        num_devices = num_devices-1
        to_remove.append(model_list[d])
        print("Removing device ", d, " with SNR ", device_SNR[d])
    else:
        if min_SNR > device_SNR[d]:
            min_SNR = device_SNR[d]
for m in to_remove:
    model_list.remove(m)
print("Number of devices left after threshold: ", num_devices, " Number of models: ", len(model_list))
# Out:
# Number of devices left after threshold:  10  Number of models:  10

# %%
#--Perform FL--
acc_history = []
for r in range(num_rounds):
    print("Communication round " + str(r+1) + "/" + str(num_rounds))
    start = time.time()
    #Train using local dataset
    for d in range(num_devices): #TODO: Parallelize
        model_list[d].fit(x_train_shards[d], y_train_shards[d], batch_size=bs, epochs=ep, verbose=0)
    #Calculate weight updates
    new_weights = []
    weight_updates = []
    for d in range(num_devices):
        new_weights.append(model_list[d].get_weights())
        weight_updates.append(new_weights[d]) #Just to initiate shape
        for l in range(len(weight_updates[d])):
            weight_updates[d][l] = new_weights[d][l] - global_weights[l]
    #Sum the weight updates
    average_update = weight_updates[0] #Just to initiate shape
    for d in range(num_devices):
        if d == 0:
            continue
        for l in range(len(average_update)):
            average_update[l] = average_update[l] + weight_updates[d][l]
    
    #When performing averaging, noise is added. I follow BAA for noise power
    for l in range(len(average_update)):
        for element in np.nditer(average_update[l], op_flags = ['readwrite']):
            element[...] = element + np.random.normal(0, np.abs(element)/min_SNR)
        average_update[l] = average_update[l]/num_devices
    
    #Update global model
    new_global = global_weights #Just to initiate shape
    for l in range(len(new_global)):
        new_global[l] = global_weights[l] + average_update[l]
    #Broadcast global model to user devices
    for model in model_list:
        model.set_weights(new_global)
    global_weights = new_global
    #Logging
    acc_history.append(model_list[0].evaluate(x_test, y_test, verbose=0)[1])
    print("Current test dataset accuracy: ", acc_history[-1])
    print(str(int(time.time()-start)) + " seconds elapsed\n")
# Out:
# Communication round 1/50
# Current test dataset accuracy:  0.9174
# 10 seconds elapsed
#
# Communication round 2/50
# Current test dataset accuracy:  0.9345
# 5 seconds elapsed
#
# Communication round 3/50
# Current test dataset accuracy:  0.9446
# 6 seconds elapsed
#
# Communication round 4/50
# Current test dataset accuracy:  0.9521
# 7 seconds elapsed
#
# Communication round 5/50
# Current test dataset accuracy:  0.9568
# 6 seconds elapsed
#
# Communication round 6/50
# Current test dataset accuracy:  0.9601
# 6 seconds elapsed
#
# Communication round 7/50
# Current test dataset accuracy:  0.9632
# 6 seconds elapsed
#
# Communication round 8/50
# Current test dataset accuracy:  0.9661
# 6 seconds elapsed
#
# Communication round 9/50
# Current test dataset accuracy:  0.968
# 6 seconds elapsed
#
# Communication round 10/50
# Current test dataset accuracy:  0.9696
# 6 seconds elapsed
#
# Communication round 11/50
# Current test dataset accuracy:  0.9709
# 7 seconds elapsed
#
# Communication round 12/50
# Current test dataset accuracy:  0.9726
# 7 seconds elapsed
#
# Communication round 13/50
# Current test dataset accuracy:  0.9726
# 7 seconds elapsed
#
# Communication round 14/50
# Current test dataset accuracy:  0.9746
# 7 seconds elapsed
#
# Communication round 15/50
# Current test dataset accuracy:  0.975
# 7 seconds elapsed
#
# Communication round 16/50
# Current test dataset accuracy:  0.9754
# 6 seconds elapsed
#
# Communication round 17/50
# Current test dataset accuracy:  0.9761
# 6 seconds elapsed
#
# Communication round 18/50
# Current test dataset accuracy:  0.9766
# 6 seconds elapsed
#
# Communication round 19/50
# Current test dataset accuracy:  0.9769
# 5 seconds elapsed
#
# Communication round 20/50
# Current test dataset accuracy:  0.9775
# 6 seconds elapsed
#
# Communication round 21/50
# Current test dataset accuracy:  0.9778
# 6 seconds elapsed
#
# Communication round 22/50
# Current test dataset accuracy:  0.9787
# 6 seconds elapsed
#
# Communication round 23/50
# Current test dataset accuracy:  0.9788
# 7 seconds elapsed
#
# Communication round 24/50
# Current test dataset accuracy:  0.9799
# 6 seconds elapsed
#
# Communication round 25/50
# Current test dataset accuracy:  0.9792
# 6 seconds elapsed
#
# Communication round 26/50
# Current test dataset accuracy:  0.98
# 7 seconds elapsed
#
# Communication round 27/50
# Current test dataset accuracy:  0.9794
# 6 seconds elapsed
#
# Communication round 28/50
# Current test dataset accuracy:  0.9798
# 7 seconds elapsed
#
# Communication round 29/50
# Current test dataset accuracy:  0.9797
# 7 seconds elapsed
#
# Communication round 30/50
# Current test dataset accuracy:  0.9803
# 7 seconds elapsed
#
# Communication round 31/50
# Current test dataset accuracy:  0.9804
# 7 seconds elapsed
#
# Communication round 32/50
# Current test dataset accuracy:  0.9804
# 8 seconds elapsed
#
# Communication round 33/50
# Current test dataset accuracy:  0.9808
# 7 seconds elapsed
#
# Communication round 34/50
# Current test dataset accuracy:  0.981
# 7 seconds elapsed
#
# Communication round 35/50
# Current test dataset accuracy:  0.981
# 6 seconds elapsed
#
# Communication round 36/50
# Current test dataset accuracy:  0.9811
# 6 seconds elapsed
#
# Communication round 37/50
# Current test dataset accuracy:  0.9801
# 7 seconds elapsed
#
# Communication round 38/50
# Current test dataset accuracy:  0.9812
# 7 seconds elapsed
#
# Communication round 39/50
# Current test dataset accuracy:  0.9813
# 6 seconds elapsed
#
# Communication round 40/50
# Current test dataset accuracy:  0.9815
# 6 seconds elapsed
#
# Communication round 41/50
# Current test dataset accuracy:  0.9811
# 6 seconds elapsed
#
# Communication round 42/50
# Current test dataset accuracy:  0.9813
# 7 seconds elapsed
#
# Communication round 43/50
# Current test dataset accuracy:  0.9814
# 7 seconds elapsed
#
# Communication round 44/50
# Current test dataset accuracy:  0.9821
# 7 seconds elapsed
#
# Communication round 45/50
# Current test dataset accuracy:  0.9818
# 8 seconds elapsed
#
# Communication round 46/50
# Current test dataset accuracy:  0.9819
# 7 seconds elapsed
#
# Communication round 47/50
# Current test dataset accuracy:  0.9813
# 6 seconds elapsed
#
# Communication round 48/50
# Current test dataset accuracy:  0.9818
# 6 seconds elapsed
#
# Communication round 49/50
# Current test dataset accuracy:  0.9818
# 6 seconds elapsed
#
# Communication round 50/50
# Current test dataset accuracy:  0.9825
# 7 seconds elapsed

# %%
#--Plot accuracy--
import matplotlib.pyplot as plt
start = 0
end = -1
fig = plt.figure()
plt.plot(range(len(acc_history[start:end])), acc_history[start:end])
plt.savefig("./plots/"+filename+".png", format='png')

# %%
#--Store history--
np_history = np.asarray(acc_history)
np_history.tofile("./acc_history/"+filename+".txt", sep=',')

# %%
#--Comparative plot--
#Get history
import numpy as np
import matplotlib.pyplot as plt
filenames = []
filenames.append("SNR-infinity-devices-10")
filenames.append("SNR-10-devices-10")
filenames.append("SNR-8-devices-10")
filenames.append("SNR-4-devices-10")
filenames.append("SNR-3-devices-10")
filenames.append("SNR-2-devices-10")
labels = []
labels.append("SNR=infinity")
labels.append("SNR=10")
labels.append("SNR=8")
labels.append("SNR=4")
labels.append("SNR=3")
labels.append("SNR=2")
histories = []
for i in range(len(filenames)):
    histories.append(np.fromfile("./acc_history/"+filenames[i]+".txt", sep=","))
#Plot
start = 0
end = -1
fig = plt.figure()
for i in range(len(filenames)):
    plt.plot(range(len(histories[i][start:end])), histories[i][start:end], label=labels[i])
plt.legend()
#plt.savefig("./plots/"+filename+".png", format='png')

# %%
#--Comparative plot 2--
#Get history
import numpy as np
import matplotlib.pyplot as plt
filenames = []
filenames.append("SNR-10-devices-10-selection-false")
filenames.append("SNR-10-devices-10-selection-true")
labels = []
labels.append("10/10 devices")
labels.append("7/10 devices")
histories = []
for i in range(len(filenames)):
    histories.append(np.fromfile("./acc_history/"+filenames[i]+".txt", sep=","))
#Plot
start = 0
end = -1
fig = plt.figure()
for i in range(len(filenames)):
    plt.plot(range(len(histories[i][start:end])), histories[i][start:end], label=labels[i])
plt.legend()
#plt.savefig("./plots/"+filename+".png", format='png')
